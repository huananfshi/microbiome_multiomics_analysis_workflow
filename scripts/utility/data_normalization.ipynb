# %%
import numpy as np
import matplotlib as plt
import pandas as pd
from sklearn import preprocessing
import seaborn as sns
from scipy.stats import shapiro,normaltest

# %%
taxa=pd.read_csv("/Users/huananshi/Box Sync/EODF_analysis/intermediate_files/humann3/taxonomic_profiles_all_species_renorm.csv",index_col=0)
gene_abun = pd.read_csv("/Users/huananshi/Box Sync/EODF_analysis/intermediate_files/humann3/ecs_cpm_all_nonspecies_name.csv", index_col=0)
plasma_metabolites = pd.read_csv("/Users/huananshi/Box Sync/EODF_analysis/intermediate_files/metabolomics/plasma_metabolites_log10.csv", index_col=0)
cecal_metabolites = pd.read_csv("/Users/huananshi/Box Sync/EODF_analysis/intermediate_files/metabolomics/cecal_metabolites_log10.csv", index_col=0)

# %%
#Humann3 taxa 
taxa=taxa.transpose()
taxa_renorm = pd.DataFrame(preprocessing.StandardScaler().fit_transform(taxa), index= taxa.index, columns= taxa.columns)

# %%
#Humann3 cpm
gene_abun_renorm = pd.DataFrame(preprocessing.StandardScaler().fit_transform(gene_abun[1:]), index= gene_abun.index[1:], columns= gene_abun.columns)
gene_abun_renorm.loc["Gene Name"] = gene_abun.loc["Gene Name"]
gene_abun_renorm = gene_abun_renorm.reindex(gene_abun.index)

# %%
#cecal_abun_renorm = pd.DataFrame(preprocessing.PowerTransformer(method='yeo-johnson').fit_transform(cecal_metabolites[3:]), index= cecal_metabolites.index[3:], columns= cecal_metabolites.columns)
#plasma_abun_renorm = pd.DataFrame(preprocessing.PowerTransformer(method='yeo-johnson').fit_transform(plasma_metabolites[3:]), index= plasma_metabolites.index[3:], columns= plasma_metabolites.columns)
#cecal_renorm = cecal_metabolites[0:3].append(cecal_abun_renorm)
#plasma_renorm = plasma_metabolites[0:3].append(plasma_abun_renorm)

# %%
sns.distplot(taxa_renorm)
# Out:
# <AxesSubplot:>

# %%
sns.distplot(gene_abun_renorm[1:])
# Out:
# <AxesSubplot:>

# %%
sns.distplot(plasma_metabolites[4:].transpose())
# Out:
# <AxesSubplot:>

# %%
sns.distplot(cecal_metabolites[4:].transpose())
# Out:
# <AxesSubplot:>

# %%
taxa_renorm.to_csv("/Users/huananshi/Box Sync/EODF_analysis/intermediate_files/humann3/taxa_renorm.csv")
gene_abun_renorm.to_csv("/Users/huananshi/Box Sync/EODF_analysis/intermediate_files/humann3/ecs_cpm_all_nonspecies_name_renorm.csv")
#plasma_renorm.to_csv("/Users/huananshi/Box Sync/EODF_analysis/intermediate_files/metabolomics/plasma_metabolites_log10_renorm.csv")
#cecal_renorm.to_csv("/Users/huananshi/Box Sync/EODF_analysis/intermediate_files/metabolomics/cecal_metabolites_log10_renorm.csv")
